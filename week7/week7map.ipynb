# %%
import geopandas as gpd
import pandas as pd

Saitama = gpd.read_file('Saitama.geojson')

Saitama.plot()
# Out:
# <Axes: >

# %%
Saitama.sample(6)
# Out:
#    N03_001 N03_002 N03_003 N03_004 N03_005 N03_007  \
# 66     埼玉県    None     秩父郡     横瀬町    None   11361
# 23     埼玉県    None    None     狭山市    None   11215
# 44     埼玉県    None    None    富士見市    None   11235
# 27     埼玉県    None    None     深谷市    None   11218
# 6      埼玉県    None    None   さいたま市      桜区   11106
# 15     埼玉県    None    None     行田市    None   11206
#
#                                              geometry
# 66  POLYGON ((139.09015 35.96377, 139.09025 35.963...
# 23  POLYGON ((139.44908 35.83333, 139.44908 35.833...
# 44  POLYGON ((139.56775 35.83333, 139.56775 35.833...
# 27  POLYGON ((139.26279 36.24514, 139.26223 36.245...
# 6   POLYGON ((139.60823 35.83333, 139.60829 35.833...
# 15  POLYGON ((139.42166 36.15080, 139.42164 36.151...

# %%
Saitama.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   N03_001   81 non-null     object
#  1   N03_002   0 non-null      object
#  2   N03_003   27 non-null     object
#  3   N03_004   81 non-null     object
#  4   N03_005   11 non-null     object
#  5   N03_007   81 non-null     object
#  6   geometry  81 non-null     geometry
# dtypes: geometry(1), object(6)
# memory usage: 4.6+ KB

# %%
Saitama_pop=pd.read_csv("Saitama_a.csv")

# %%
Saitama_pop.head()
# Out:
#       KEY_CODE  HYOSYO CITYNAME   NAME  HTKSYORI  HTKSAKI  GASSAN   人口総数  \
# 0        11101       1  さいたま市西区    NaN         0      NaN     NaN  93499
# 1    111010010       2  さいたま市西区    宮前町         0      NaN     NaN   3327
# 2    111010020       3  さいたま市西区     三橋         0      NaN     NaN  13439
# 3  11101002005       4  さいたま市西区  三橋五丁目         0      NaN     NaN   3643
# 4  11101002006       4  さいたま市西区  三橋六丁目         0      NaN     NaN   9796
#
#        男      女   世帯総数
# 0  45843  47656  38197
# 1   1665   1662   1360
# 2   6683   6756   5564
# 3   1806   1837   1550
# 4   4877   4919   4014

# %%
Saitama_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7095 entries, 0 to 7094
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   KEY_CODE  7095 non-null   int64
#  1   HYOSYO    7095 non-null   int64
#  2   CITYNAME  7095 non-null   object
#  3   NAME      7023 non-null   object
#  4   HTKSYORI  7095 non-null   int64
#  5   HTKSAKI   0 non-null      float64
#  6   GASSAN    0 non-null      float64
#  7   人口総数      7095 non-null   object
#  8   男         7095 non-null   object
#  9   女         7095 non-null   object
#  10  世帯総数      7095 non-null   object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 609.9+ KB

# %%
Saitama.rename(columns={'N03_007':'KEY_CODE'},inplace=True)

# %%
Saitama
# Out:
#    N03_001 N03_002 N03_003 N03_004 N03_005 KEY_CODE  \
# 0      埼玉県    None    None   さいたま市      西区    11101
# 1      埼玉県    None    None   さいたま市      西区    11101
# 2      埼玉県    None    None   さいたま市      北区    11102
# 3      埼玉県    None    None   さいたま市     大宮区    11103
# 4      埼玉県    None    None   さいたま市     見沼区    11104
# ..     ...     ...     ...     ...     ...      ...
# 76     埼玉県    None     児玉郡     上里町    None    11385
# 77     埼玉県    None     大里郡     寄居町    None    11408
# 78     埼玉県    None    南埼玉郡     宮代町    None    11442
# 79     埼玉県    None    北葛飾郡     杉戸町    None    11464
# 80     埼玉県    None    北葛飾郡     松伏町    None    11465
#
#                                              geometry
# 0   POLYGON ((139.59147 35.88046, 139.59167 35.880...
# 1   POLYGON ((139.54427 35.93715, 139.54376 35.937...
# 2   POLYGON ((139.59680 35.91567, 139.59724 35.915...
# 3   POLYGON ((139.59706 35.89167, 139.59717 35.891...
# 4   POLYGON ((139.64921 35.90143, 139.64831 35.901...
# ...

# %%
Saitama['KEY_CODE'] = Saitama['KEY_CODE'].astype(int)

# %%
Saitama.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   N03_001   81 non-null     object
#  1   N03_002   0 non-null      object
#  2   N03_003   27 non-null     object
#  3   N03_004   81 non-null     object
#  4   N03_005   11 non-null     object
#  5   KEY_CODE  81 non-null     int64
#  6   geometry  81 non-null     geometry
# dtypes: geometry(1), int64(1), object(5)
# memory usage: 4.6+ KB

# %%
Saitama_pop=Saitama.merge(Saitama_pop,on="KEY_CODE")

# %%
Saitama.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   N03_001   81 non-null     object
#  1   N03_002   0 non-null      object
#  2   N03_003   27 non-null     object
#  3   N03_004   81 non-null     object
#  4   N03_005   11 non-null     object
#  5   KEY_CODE  81 non-null     int64
#  6   geometry  81 non-null     geometry
# dtypes: geometry(1), int64(1), object(5)
# memory usage: 4.6+ KB

# %%
Saitama_pop['人口総数'] = Saitama_pop['人口総数'].astype(int)

# %%
Saitama_pop.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   N03_001   81 non-null     object
#  1   N03_002   0 non-null      object
#  2   N03_003   27 non-null     object
#  3   N03_004   81 non-null     object
#  4   N03_005   11 non-null     object
#  5   KEY_CODE  81 non-null     int64
#  6   geometry  81 non-null     geometry
#  7   HYOSYO    81 non-null     int64
#  8   CITYNAME  81 non-null     object
#  9   NAME      0 non-null      object
#  10  HTKSYORI  81 non-null     int64
#  11  HTKSAKI   0 non-null      float64
#  12  GASSAN    0 non-null      float64
#  13  人口総数      81 non-null     int64
#  14  男         81 non-null     object
#  15  女         81 non-null     object
#  16  世帯総数      81 non-null     object
# dtypes: float64(2), geometry(1), int64(4), object(10)
# memory usage: 10.9+ KB

# %%
Saitama_pop.plot(column='人口総数',legend=True,figsize=(10,10))
# Out:
# <Axes: >

# %%
Saitama_pop.plot(figsize=(10,10),
                  column='人口総数',
                  legend=True,
                  cmap='seismic')
# Out:
# <Axes: >
